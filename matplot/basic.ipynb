# %% [markdown]
# #### Matplotlib

# %%
# ! pip install matplotlib

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Graph 
# plot
# scatter
# hist 
# bar 
# pie

# %% [markdown]
# ##### plot

# %%
x_point = [1,2,3,4,5]
y_point = [1,4,9,16,25] ### array of x and y point
plt.plot(x_point,y_point)
plt.show()

# %%
x_point = [0,6]
y_point = [0,50]
plt.plot(x_point, y_point, 'o') ### o is used to create scatter plot 
plt.show() ## show the output

# %%
x_point = [1,8]
plt.plot(x_point, marker = 'o') ## 
plt.show()

# %%
xpoint = [1,2,3,4,5,6]
plt.plot(xpoint, marker = 'o')
plt.show()

# %%
xpoint =np.array([1,5,6,9])

# %%
xpoint
# Out:
# array([1, 5, 6, 9])

# %%
plt.plot(xpoint, marker = '*')
plt.show()

# %%
xpoint =np.array([1,2,3,4])
plt.plot(xpoint, 'o:b') ### os is used to create scatter plot and :b is used to create blank line 
plt.show()

# %%
xpoint =np.array([1,2,3,4,5])
plt.plot(xpoint, marker = 'o', ms = 30 )
plt.show()

# %%
x=np.array([1,2,3,5,4])
plt.plot(x , marker = '*', ms = 30, mec = 'r')
plt.show()

# %%
x =np.array([1,2,4,5,6 ])
plt.plot(x, marker = '*', ms = 30 , mec = 'r', mfc = 'g')
plt.show()

# %%
x =np.array([1,3,5,7,3])
plt.plot(x , ls = 'dotted')
plt.show()

# %%
x =np.array([1,5,6,3,2])
plt.plot(x , ls = 'dashed')
plt.show()

# %%
x =np.array([1,2,3,4,5,7])
plt.plot(x , linewidth = 5 )
plt.show()

# %%
x = np.array([1,2,3,4])
y = np.array([2,5,8,4])
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x=np.array([1,2,3,4])
y =np.array([4,5,6,7])
plt.xlabel("x data point")
plt.ylabel("y data point")
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x=np.array([1,2,3,4])
y =np.array([4,5,6,7])
plt.title("x and y data point ")
plt.xlabel("x data point")
plt.ylabel("y data point")
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x=np.array([1,2,3,4])
y =np.array([4,5,6,7])
plt.title("x and y data point ")
plt.xlabel("x data point")
plt.ylabel("y data point")
plt.grid()
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,3,5,6,6])
plt.subplot(1,2,1)
plt.plot(x , y )
x = np.array([1,2,3,4,5])
y = np.array([1,3,5,3,6])
plt.subplot(1,2,2)
plt.plot(x , y )
plt.show()

# %%
### Scatter plot 
x = np.array([1,2,3,4,5])
y = np.array([1,2,4,6,7])
plt.scatter(x,y)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,2,4,6,7])
plt.scatter(x,y)

x = np.array([1,8,6,4,5])
y = np.array([1,2,9,6,7])
plt.scatter(x,y)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,2,4,6,7])
colour =np.array(['red','green','blue','yellow','black'])

plt.scatter(x,y, c= colour,alpha= 0.5 )
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,2,4,6,7])
colour =np.array(['red','green','blue','yellow','black'])
size =np.array([10,20,30,40,50])
plt.scatter(x,y, c= colour,alpha= 0.5, s =size )
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c )
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c, cmap= 'coolwarm' )
plt.colorbar()
plt.show()
# Out:
# C:\Users\kumaw\AppData\Local\Temp\ipykernel_11780\223587407.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, s = sizes, c = c, cmap= 'coolwarm' )

# %%
### barplot 
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.barh(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y, color = 'green')
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y, width = 0.1)
plt.show()

# %%
## hist plot 
x =np.random.normal(170,10,250)

# %%
# x

# %%
plt.hist(x)
# Out:
# (array([ 1.,  8., 18., 41., 53., 39., 39., 33., 12.,  6.]),
#  array([142.25881469, 147.46076977, 152.66272484, 157.86467992,
#         163.06663499, 168.26859007, 173.47054514, 178.67250022,
#         183.87445529, 189.07641037, 194.27836544]),
#  <BarContainer object of 10 artists>)

# %%
#pie

# %%
x=np.array([1,2,3,4])
labels = ['a','b','c','d']
plt.pie(x, labels = labels)
plt.show()

# %%
x=np.array([1,2,3,4])
labels = ['a','b','c','d']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = labels,explode = myexplode)
plt.show()

# %%
x=np.array([1,2,3,4])
labels = ['a','b','c','d']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = labels,explode = myexplode, shadow = True )
plt.show()

# %%
colour = ['red','green','blue','yellow']
x=np.array([1,2,3,4])
labels = ['a','b','c','d']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = labels,explode = myexplode, shadow = True, colors = colour)
plt.show()

# %%
colour = ['red','green','blue','yellow']
x=np.array([1,2,3,4])
labels = ['a','b','c','d']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = labels,explode = myexplode, shadow = True, colors = colour, autopct = '%1.1f%%')
plt.show()

# %%
colour = ['red','green','blue','yellow']
x=np.array([1,2,3,4])
labels = ['a','b','c','d']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = labels,explode = myexplode, shadow = True, colors = colour, autopct = '%1.1f%%')
plt.legend('my pie chart')
plt.show()
